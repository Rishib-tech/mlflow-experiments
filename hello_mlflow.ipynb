# %% [markdown]
# # MLFlow Tracking Server

# %%
import mlflow

# %%
mlflow.get_tracking_uri()
# Out:
# 'sqlite:///C:/Users/rishi/OneDrive/Documents/Udemy_courses/End-to-End%20MLOps%20Bootcamp/MLflow/mlflow.db'

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("Check localhost connection")

with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("rishi",2)
# Out:
# 🏃 View run carefree-ray-525 at: http://127.0.0.1:5000/#/experiments/1/runs/9fde6c3649d647b294fe042a30e096fb
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("rishi1",2)
# Out:
# 🏃 View run rumbling-kit-121 at: http://127.0.0.1:5000/#/experiments/1/runs/a8e4e98decaf47d5bf1fe6c9c2665f84
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
